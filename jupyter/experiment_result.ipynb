# %%
import pandas as pd
import numpy as np

# %%
# import numpy as np
# import matplotlib as mat
# from matplotlib import rc

# # font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/Arial.ttf").get_name()
# # font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/NANUMBARUNPENR.TTF").get_name()


# def setPlotStyle():
#     # plt.figure(dpi=300)
#     # mat.rcParams["font.family"] = font_name
#     mat.rcParams["font.size"] = 25
#     mat.rcParams["legend.fontsize"] = 25
#     mat.rcParams["lines.linewidth"] = 2
#     mat.rcParams["lines.color"] = "r"
#     mat.rcParams["axes.grid"] = 1
#     mat.rcParams["axes.xmargin"] = 0.1
#     mat.rcParams["axes.ymargin"] = 0.1
#     mat.rcParams["mathtext.fontset"] = "dejavuserif"  # "cm", "stix", etc.
#     mat.rcParams["figure.dpi"] = 500
#     mat.rcParams["savefig.dpi"] = 500
# # setPlotStyle()

# %%
data = [100, 100, 100, 100, 100, 100, 100, 
        100,  120,  140,  160,  180,  200, 
        200,  240, 280,  320,  360,  400, 
        400,  460,  520,  580,  640,  700]
        # 700,  780,  860, 940,  1020, 1100,
        # 1100, 1200, 1300, 1400, 1500, 1600]
df = pd.DataFrame(data, columns=['Requests'])

import matplotlib 
matplotlib.rcParams.update({'font.size': 17})
import matplotlib.pyplot as plt
interval = 11
xlim = len(data) * 10
plt.figure(figsize=(10,5))
# for sd in social_deployment:
#     if sd == "nginx-thrift":
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd], 'ob--')
#     else:
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd])
#     plt.yticks(np.arange(0,2000,100))
#     plt.xticks(np.arange(0,xlim,60))

plt.plot(df.index * 10, df, 'og--')
# plt.yticks(np.arange(0,2000,100))
plt.xticks(np.arange(0,xlim,30))
plt.xlabel('Time(s)')
plt.ylabel('Requests per second')
# plt.title('(a) Linear Workload')
# plt.legend(df, fontsize=12, loc='best')
plt.grid()  # 그리드
# plt.ylim(0, 850)
plt.xlim(0, xlim)

plt.show()

# %%
data = [100, 100, 100, 100, 100, 100, 100, 
        200, 200, 200, 200, 200, 200, 
        400, 400, 400, 400, 400, 400, 
        700, 700, 700, 700, 700, 700]
        # 700,  780,  860, 940,  1020, 1100,
        # 1100, 1200, 1300, 1400, 1500, 1600]
df = pd.DataFrame(data, columns=['Requests'])

import matplotlib.pyplot as plt
interval = 11
xlim = len(data) * 10
plt.figure(figsize=(10,5))
# for sd in social_deployment:
#     if sd == "nginx-thrift":
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd], 'ob--')
#     else:
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd])
#     plt.yticks(np.arange(0,2000,100))
#     plt.xticks(np.arange(0,xlim,60))

plt.plot(df.index * 10, df, 'or--')
# plt.yticks(np.arange(0,2000,100))
plt.xticks(np.arange(0,xlim,30))
plt.xlabel('Time(s)')
plt.ylabel('Requests per second')
# plt.title('(b) Spike Workload')
# plt.legend(df, fontsize=12, loc='best')
plt.grid()  # 그리드
# plt.ylim(0, 2000)
plt.xlim(0, xlim)

plt.show()

# %%
import pandas as pd
import numpy as np

default = [
111115,
76965,
90943,
101209,
77623,
91390,
89841,
67078,
85044,
52702,
111548,
107517,
60949,
56728,
54405,
52540,
103910,
52765,
75013,
53109,
109122,
116806,
57077,
44065,
100092,
84004,
89190,
52057,
61996,
108831
]

optimal = [
28057,
30949,
40525,
38797,
31599,
32075,
32978,
38928,
33244,
37061,
35979,
35046,
34122,
23873,
34082,
28476,
35040,
39719,
44631,
32955,
28155,
34115,
24033,
17937,
30065,
34017,
34835,
23018,
49543,
44778
]
upstream = [
2171,
3839,
3975,
4863,
4377,
5413,
3990,
4666,
4057,
4764,
2970,
2198,
5084,
3283,
2947,
5064,
3611,
4887,
3639,
3652,
3897,
3972,
4001,
3785,
3597,
5085,
4055,
4066,
4206,
3146
]

import matplotlib.pyplot as plt
import numpy as np
# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n, 1)

# setPlotStyle()
import matplotlib 
matplotlib.rcParams.update({'font.size': 17})
ylim = 130
default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
upstream = list(map(get_seconds, upstream))
plt.figure(figsize=(6.5,4))
test_cnt = 30
x = list(range(1, test_cnt+1))
plt.xlabel('Test #')
plt.ylabel('Scaling Latency(s)')
# plt.title('Scaling Latency of ')

plt.yticks(np.arange(0,ylim,20))

plt.ylim(0, ylim)
plt.xlim(0, test_cnt+1)

# fig, ax = plt.subplots()    
color = 'tab:blue'
plt.scatter(x, default, c=color, s=30, label="Default",
            alpha=1, edgecolors='none')

color = 'tab:orange'
plt.scatter(x, optimal, c=color, s=30, label="Optimal",
            alpha=1, edgecolors='none', marker='s')

color = 'tab:green'
plt.scatter(x, upstream, c=color, s=30, label="Proposed",
            alpha=1, edgecolors='none', marker='D')


# handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
# plt.legend(handles, labels, 
plt.legend(loc="upper right", title="Mode",fontsize=10, title_fontsize=12)
# plt.grid(False)
plt.grid(axis='y')
# plt.scatter(x, default, c="tab:blue", alpha=0.95, edgecolors='none')
# plt.scatter(x, optimal)

plt.show()

# %%
default = [
111115,
76965,
90943,
101209,
77623,
91390,
89841,
67078,
85044,
52702,
111548,
107517,
60949,
56728,
54405,
52540,
103910,
52765,
75013,
53109,
109122,
116806,
57077,
44065,
100092,
84004,
89190,
52057,
61996,
108831
]

optimal = [
28057,
30949,
40525,
38797,
31599,
32075,
32978,
38928,
33244,
37061,
35979,
35046,
34122,
23873,
34082,
28476,
35040,
39719,
44631,
32955,
28155,
34115,
24033,
17937,
30065,
34017,
34835,
23018,
49543,
44778
]
upstream = [
2171,
3839,
3975,
4863,
4377,
5413,
3990,
4666,
4057,
4764,
2970,
2198,
5084,
3283,
2947,
5064,
3611,
4887,
3639,
3652,
3897,
3972,
4001,
3785,
3597,
5085,
4055,
4066,
4206,
3146
]

matplotlib.rcParams.update({'font.size': 17})
all_data = [np.random.normal(0, std, size=5) for std in range(1, 3)]
# labels = ['Default', 'x2', 'x3']
print(all_data)


# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n, 1)


default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
upstream = list(map(get_seconds, upstream))


all_data = []
all_data.append(default)
all_data.append(optimal)
all_data.append(upstream)


labels = ["Default", "Optimal", "Proposed"]
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6.5, 4))


# rectangular box plot
bplot1 = ax.boxplot(
    all_data,
    vert=True,  # vertical box alignment
    patch_artist=True,  # fill with color
    labels=labels,
    #  showmeans=True,
    #  meanline=True
)  # will be used to label x-ticks

plt.ylabel('Scaling Latency(s)')
colors = ["tab:blue", "tab:orange"]
for patch, color in zip(bplot1["boxes"], colors):
    patch.set_facecolor(color)

for i, _ in enumerate(labels):
    
    if i != 2:        
        mean_line = bplot1["medians"][i]  # 평균값 요소에 접근    
        mean_line.set_color("k")  # 평균값 선 색상 변경
        mean_line.set_linewidth(1.0)  # 평균값 선 굵기 변경
    else:        
        mean_line = bplot1["medians"][i]  # 평균값 요소에 접근            
        mean_line.set_linewidth(0.0)  # 평균값 선 굵기 변경
        mean_line = None
#         mean_line.set_linestyle(None)
    
        
ax.yaxis.grid(True)
ax.set_xlabel(" ")

ax.yaxis.grid(True)
ax.set_xlabel(" ")


axins = ax.inset_axes([0.6, 0.5, 0.3, 0.3], xlim=(2.8, 3.2), ylim=(2, 6))

bplot2 = axins.boxplot(
    upstream,
    vert=True,  # vertical box alignment
    patch_artist=True,  # fill with color
    labels=[""],
    positions=[3],
)

mean_line = bplot2["medians"][0]  # 평균값 요소에 접근
mean_line.set_color("k")  # 평균값 선 색상 변경
mean_line.set_linewidth(1.0)  # 평균값 선 굵기 변경

colors = ["tab:green"]
for patch, color in zip(bplot2["boxes"], colors):
    patch.set_facecolor(color)

for axis in ["top", "bottom", "left", "right"]:
    axins.spines[axis].set_linewidth(1.5)


axins.set_ylim(1, 5)
axins.set_yticks(np.arange(2, 7, 2))
indicator = ax.indicate_inset_zoom(axins)

ylim = 120
plt.yticks(np.arange(0, ylim, 20))
plt.ylim(0, ylim)
plt.show()
# Out:
# [array([ 0.92543694, -0.11448243, -0.87289843, -0.63374734, -0.91379241]), array([-1.79622520e+00,  1.98512080e-03, -2.53824418e+00, -3.17329045e+00,
#        -1.42896953e+00])]

# %%
import matplotlib.pyplot as plt

# CPU limit values as x-axis
cpu_limits = [1.0, 1.5, 2.0, 2.5]

default = [
2,
1.8,
1.2,
1,
1,
2.2,
2.2,
2,
2,
1,
1,
2.4,
2.2,
2,
2,
1.4,
1,
2.6,
2.2,
2.2,
2,
1.6,
1,
3.4,    
]
uhpa = [
3.8,
3.2,
2.4,
1.8,
1,
4.2,
5.2,
4.2,
3,
2.4,
1.4,
5.4,
6.6,
4.8,
4.2,
3.2,
1.6,
7.2,
8.4,
6.8,
4.6,
4,
2.4,
8,

]
optimal = [
2.4,
2,
2,
1,
1,
2.6,
3.2,
2.6,
2,
1.6,
1,
3.4,
3.6,
2.8,
2.4,
2,
1,
4.4,
4,
3.4,
2.4,
2,
1.2,
4.8,
]


import matplotlib 
matplotlib.rcParams.update({'font.size': 19})
axs = [None, None, None]
axs2 = [None, None, None]
axs3 = [None, None, None]
fig, ((axs), (axs2), (axs3)) = plt.subplots(nrows=3, ncols=2, figsize=(15,15))
plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
titles = [
    "compose-post-service",
    "home-timeline-service",
    "post-storage-service",
    "text-service",
    "user-mention-service",
    "user-timeline-service",
]
indexs = [0, 6, 12, 18]


def extract_list(l, n):
    _l = []
    for idx in indexs:
        _l.append(l[idx + n])
    return _l


for i in range(0, int(len(default) / 4)):
    if i < 2:
        axs[i].plot(
            cpu_limits,
            extract_list(default, i),
            marker="o",
            color="blue",
            linestyle="-",
            label="Default",
        )
        axs[i].plot(
            cpu_limits,
            extract_list(optimal, i),
            marker="s",
            color="green",
            linestyle="--",
            label="Optimal",
        )
        axs[i].plot(
            cpu_limits,
            extract_list(uhpa, i),
            marker="D",
            color="red",
            linestyle="-.",
            label="Proposed",
        )

        axs[i].set_xlabel("CPU Limits")
        axs[i].set_ylabel("Number of Pods")
        axs[i].set_title(titles[i])
        axs[i].set_xticks(np.arange(1, 3, 0.5))
# axs[0].legend(loc="upper center", bbox_to_anchor=(0.0, 0), ncol=1)
axs[0].legend(loc="upper left", title="",fontsize=13, title_fontsize=12, ncol=3)

plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
for i in range(0, int(len(default) / 4)):
    if i > 1 and i < 4:
        axs2[i - 2].plot(
            cpu_limits,
            extract_list(default, i),
            marker="o",
            color="blue",
            linestyle="-",
            label="Default",
        )
        axs2[i - 2].plot(
            cpu_limits,
            extract_list(optimal, i),
            marker="s",
            color="green",
            linestyle="--",
            label="Optimal",
        )
        axs2[i - 2].plot(
            cpu_limits,
            extract_list(uhpa, i),
            marker="D",
            color="red",
            linestyle="-.",
            label="Proposed",
        )

        axs2[i - 2].set_xlabel("CPU Limits")
        axs2[i - 2].set_ylabel("Number of Pods")
        axs2[i - 2].set_title(titles[i])
        axs2[i - 2].set_xticks(np.arange(1, 3, 0.5))

plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
for i in range(0, int(len(default) / 4)):
    if i > 3:
        axs3[i - 4].plot(
            cpu_limits,
            extract_list(default, i),
            marker="o",
            color="blue",
            linestyle="-",
            label="Default",
        )
        axs3[i - 4].plot(
            cpu_limits,
            extract_list(optimal, i),
            marker="s",
            color="green",
            linestyle="--",
            label="Optimal",
        )
        axs3[i - 4].plot(
            cpu_limits,
            extract_list(uhpa, i),
            marker="D",
            color="red",
            linestyle="-.",
            label="Proposed",
        )

        axs3[i - 4].set_xlabel("CPU Limits")
        axs3[i - 4].set_ylabel("Number of Pods")
        axs3[i - 4].set_title(titles[i])
        axs3[i - 4].set_xticks(np.arange(1, 3, 0.5))

# xlim = len(data) * 10
axs[0].set_yticks(np.arange(1, 11, 1))
axs[1].set_yticks(np.arange(1, 11, 1))
axs2[0].set_yticks(np.arange(1, 8, 1))
axs2[1].set_yticks(np.arange(1, 6, 1))
axs3[0].set_yticks(np.arange(1, 4, 1))
axs3[1].set_yticks(np.arange(1, 11, 1))
# plt.yticks(np.arange(1, 10, 1))

plt.tight_layout()

# %%
import matplotlib.pyplot as plt

# CPU limit values as x-axis
cpu_limits = [1.0, 1.5, 2.0, 2.5]

default = [
2,
1.8,
2,
1,
1,
2,
2.6,
2,
2,
1.2,
1,
3,
3,
2.2,
2,
1.6,
1,
3.4,
3.6,
3,
2.2,
2,
1,
4.4
]
uhpa = [
4.8,
3.4,
2.8,
2,
1,
6,
7.4,
5.8,
4.2,
3.6,
1.8,
6.6,
8,
6.8,
5,
4,
2.4,
8.8,
8.8,
8.2,
6.2,
5.2,
2.4,
10,

]
optimal = [
2.8,
2.4,
2,
1.4,
1,
3,
2.8,
2.4,
2.2,
1.2,
1.2,
3.8,
4.2,
3.4,
3,
2,
1.2,
5.2,
5.2,
4,
3.4,
2.6,
1.2,
6.2,
]


import matplotlib 
matplotlib.rcParams.update({'font.size': 19})
axs = [None, None, None]
axs2 = [None, None, None]
axs3 = [None, None, None]
fig, ((axs), (axs2), (axs3)) = plt.subplots(nrows=3, ncols=2, figsize=(15,15))
plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
titles = [
    "compose-post-service",
    "home-timeline-service",
    "post-storage-service",
    "text-service",
    "user-mention-service",
    "user-timeline-service",
]
indexs = [0, 6, 12, 18]


def extract_list(l, n):
    _l = []
    for idx in indexs:
        _l.append(l[idx + n])
    return _l


for i in range(0, int(len(default) / 4)):
    if i < 2:
        axs[i].plot(
            cpu_limits,
            extract_list(default, i),
            marker="o",
            color="blue",
            linestyle="-",
            label="Default",
        )
        axs[i].plot(
            cpu_limits,
            extract_list(optimal, i),
            marker="s",
            color="green",
            linestyle="--",
            label="Optimal",
        )
        axs[i].plot(
            cpu_limits,
            extract_list(uhpa, i),
            marker="D",
            color="red",
            linestyle="-.",
            label="Proposed",
        )

        axs[i].set_xlabel("CPU Limits")
        axs[i].set_ylabel("Number of Pods")
        axs[i].set_title(titles[i])
        axs[i].set_xticks(np.arange(1, 3, 0.5))
# axs[0].legend(loc="upper center", bbox_to_anchor=(0.0, 0), ncol=1)
axs[0].legend(loc="upper left", title="",fontsize=13, title_fontsize=12, ncol=3)

plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
for i in range(0, int(len(default) / 4)):
    if i > 1 and i < 4:
        axs2[i - 2].plot(
            cpu_limits,
            extract_list(default, i),
            marker="o",
            color="blue",
            linestyle="-",
            label="Default",
        )
        axs2[i - 2].plot(
            cpu_limits,
            extract_list(optimal, i),
            marker="s",
            color="green",
            linestyle="--",
            label="Optimal",
        )
        axs2[i - 2].plot(
            cpu_limits,
            extract_list(uhpa, i),
            marker="D",
            color="red",
            linestyle="-.",
            label="Proposed",
        )

        axs2[i - 2].set_xlabel("CPU Limits")
        axs2[i - 2].set_ylabel("Number of Pods")
        axs2[i - 2].set_title(titles[i])
        axs2[i - 2].set_xticks(np.arange(1, 3, 0.5))

plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
for i in range(0, int(len(default) / 4)):
    if i > 3:
        axs3[i - 4].plot(
            cpu_limits,
            extract_list(default, i),
            marker="o",
            color="blue",
            linestyle="-",
            label="Default",
        )
        axs3[i - 4].plot(
            cpu_limits,
            extract_list(optimal, i),
            marker="s",
            color="green",
            linestyle="--",
            label="Optimal",
        )
        axs3[i - 4].plot(
            cpu_limits,
            extract_list(uhpa, i),
            marker="D",
            color="red",
            linestyle="-.",
            label="Proposed",
        )

        axs3[i - 4].set_xlabel("CPU Limits")
        axs3[i - 4].set_ylabel("Number of Pods")
        axs3[i - 4].set_title(titles[i])
        axs3[i - 4].set_xticks(np.arange(1, 3, 0.5))

# xlim = len(data) * 10
# axs[0].set_xticks(np.arange(1, 3, 0.5))
# plt.xticks(np.arange(1, 3, 0.5))

axs[0].set_yticks(np.arange(1, 11, 1))
axs[1].set_yticks(np.arange(1, 11, 1))
axs2[0].set_yticks(np.arange(1, 8, 1))
axs2[1].set_yticks(np.arange(1, 6, 1))
axs3[0].set_yticks(np.arange(1, 4, 1))
axs3[1].set_yticks(np.arange(1, 11, 1))

plt.tight_layout()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CPU limit values as x-axis
cpu_limits = [1.0, 1.5, 2.0, 2.5]

default = [
2,
1.8,
1.2,
1,
1,
2.2,
2.2,
2,
2,
1,
1,
2.4,
2.2,
2,
2,
1.4,
1,
2.6,
2.2,
2.2,
2,
1.6,
1,
3.4,    
]
uhpa = [
3.8,
3.2,
2.4,
1.8,
1,
4.2,
5.2,
4.2,
3,
2.4,
1.4,
5.4,
6.6,
4.8,
4.2,
3.2,
1.6,
7.2,
8.4,
6.8,
4.6,
4,
2.4,
8,

]
optimal = [
2.4,
2,
2,
1,
1,
2.6,
3.2,
2.6,
2,
1.6,
1,
3.4,
3.6,
2.8,
2.4,
2,
1,
4.4,
4,
3.4,
2.4,
2,
1.2,
4.8,
]


import matplotlib 
matplotlib.rcParams.update({'font.size': 13})
axs = [None, None, None]
axs2 = [None, None, None]
axs3 = [None, None, None]
fig, (axs) = plt.subplots(nrows=1, ncols=6, figsize=(15,5))
plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
titles = [
    "compose-post",
    "home-timeline",
    "post-storage",
    "text",
    "user-mention",
    "user-timeline",
]
indexs = [0, 6, 12, 18]

def extract_list(l, n):
    _l = []
    for idx in indexs:
        _l.append(l[idx + n])
    return _l


for i in range(0, int(len(default) / 4)):
    axs[i].plot(
        cpu_limits,
        extract_list(default, i),
        marker="o",
        color="blue",
        linestyle="-",
        label="Default",
    )
    axs[i].plot(
        cpu_limits,
        extract_list(optimal, i),
        marker="s",
        color="green",
        linestyle="--",
        label="Optimal",
    )
    axs[i].plot(
        cpu_limits,
        extract_list(uhpa, i),
        marker="D",
        color="red",
        linestyle="-.",
        label="Proposed",
    )

    axs[i].set_xlabel("CPU Limits",fontsize=14)
    axs[i].set_title(titles[i])
    axs[i].set_xticks(np.arange(1, 3, 0.5))
axs[0].set_ylabel("Number of Pods",fontsize=14)
# axs[0].legend(loc="upper center", bbox_to_anchor=(0.0, 0), ncol=1)
axs[0].legend(loc="upper center", title="",fontsize=13, title_fontsize=12, ncol=3, bbox_to_anchor=(1.2, 1.4),)

axs[0].set_yticks(np.arange(1, 11, 2))
axs[1].set_yticks(np.arange(1, 11, 2))
axs[2].set_yticks(np.arange(1, 8, 2))
axs[3].set_yticks(np.arange(1, 6, 1))
axs[4].set_yticks(np.arange(1, 4, 1))
axs[5].set_yticks(np.arange(1, 12, 2))
# plt.yticks(np.arange(1, 10, 1))

# plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# CPU limit values as x-axis
cpu_limits = [1.0, 1.5, 2.0, 2.5]

default = [
2,
1.8,
2,
1,
1,
2,
2.6,
2,
2,
1.2,
1,
3,
3,
2.2,
2,
1.6,
1,
3.4,
3.6,
3,
2.2,
2,
1,
4.4
]
uhpa = [
4.8,
3.4,
2.8,
2,
1,
6,
7.4,
5.8,
4.2,
3.6,
1.8,
6.6,
8,
6.8,
5,
4,
2.4,
8.8,
8.8,
8.2,
6.2,
5.2,
2.4,
10,

]
optimal = [
2.8,
2.4,
2,
1.4,
1,
3,
2.8,
2.4,
2.2,
1.2,
1.2,
3.8,
4.2,
3.4,
3,
2,
1.2,
5.2,
5.2,
4,
3.4,
2.6,
1.2,
6.2,
]


import matplotlib 
matplotlib.rcParams.update({'font.size': 13})
axs = [None, None, None]
axs2 = [None, None, None]
axs3 = [None, None, None]
fig, (axs) = plt.subplots(nrows=1, ncols=6, figsize=(15,5))
plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)
titles = [
    "compose-post",
    "home-timeline",
    "post-storage",
    "text",
    "user-mention",
    "user-timeline",
]
indexs = [0, 6, 12, 18]

def extract_list(l, n):
    _l = []
    for idx in indexs:
        _l.append(l[idx + n])
    return _l


for i in range(0, int(len(default) / 4)):
    axs[i].plot(
        cpu_limits,
        extract_list(default, i),
        marker="o",
        color="blue",
        linestyle="-",
        label="Default",
    )
    axs[i].plot(
        cpu_limits,
        extract_list(optimal, i),
        marker="s",
        color="green",
        linestyle="--",
        label="Optimal",
    )
    axs[i].plot(
        cpu_limits,
        extract_list(uhpa, i),
        marker="D",
        color="red",
        linestyle="-.",
        label="Proposed",
    )

    axs[i].set_xlabel("CPU Limits",fontsize=14)
    axs[i].set_title(titles[i])
    axs[i].set_xticks(np.arange(1, 3, 0.5))
axs[0].set_ylabel("Number of Pods",fontsize=14)
# axs[0].legend(loc="upper center", bbox_to_anchor=(0.0, 0), ncol=1)
axs[0].legend(loc="upper center", title="",fontsize=13, title_fontsize=12, ncol=3, bbox_to_anchor=(1.2, 1.4),)

axs[0].set_yticks(np.arange(1, 11, 2))
axs[1].set_yticks(np.arange(1, 11, 2))
axs[2].set_yticks(np.arange(1, 8, 2))
axs[3].set_yticks(np.arange(1, 6, 1))
axs[4].set_yticks(np.arange(1, 4, 1))
axs[5].set_yticks(np.arange(1, 12, 2))
# plt.yticks(np.arange(1, 10, 1))

# plt.tight_layout()
plt.show()

# %%
default = [
111115,
76965,
90943,
101209,
77623,
91390,
89841,
67078,
85044,
52702,
111548,
107517,
60949,
56728,
54405,
52540,
103910,
52765,
75013,
53109,
109122,
116806,
57077,
44065,
100092,
84004,
89190,
52057,
61996,
108831
]

optimal = [
28057,
30949,
40525,
38797,
31599,
32075,
32978,
38928,
33244,
37061,
35979,
35046,
34122,
23873,
34082,
28476,
35040,
39719,
44631,
32955,
28155,
34115,
24033,
17937,
30065,
34017,
34835,
23018,
49543,
44778
]
upstream = [
2171,
3839,
3975,
4863,
4377,
5413,
3990,
4666,
4057,
4764,
2970,
2198,
5084,
3283,
2947,
5064,
3611,
4887,
3639,
3652,
3897,
3972,
4001,
3785,
3597,
5085,
4055,
4066,
4206,
3146
]


for i in range(len(upstream)):
    print(i+1, round(default[i]*0.001,2), round(optimal[i]*0.001,2), round(upstream[i]*0.001,2))
# Out:
# 1 111.12 28.06 2.17
# 2 76.97 30.95 3.84
# 3 90.94 40.52 3.98
# 4 101.21 38.8 4.86
# 5 77.62 31.6 4.38
# 6 91.39 32.08 5.41
# 7 89.84 32.98 3.99
# 8 67.08 38.93 4.67
# 9 85.04 33.24 4.06
# 10 52.7 37.06 4.76
# 11 111.55 35.98 2.97
# 12 107.52 35.05 2.2
# 13 60.95 34.12 5.08
# 14 56.73 23.87 3.28
# 15 54.41 34.08 2.95
# 16 52.54 28.48 5.06
# 17 103.91 35.04 3.61
# 18 52.77 39.72 4.89
# 19 75.01 44.63 3.64
# 20 53.11 32.95 3.65
# 21 109.12 28.16 3.9
# 22 116.81 34.12 3.97
# 23 57.08 24.03 4.0
# 24 44.06 17.94 3.79
# 25 100.09 30.07 3.6
# 26 84.0 34.02 5.08
# 27 89.19 34.84 4.05
# 28 52.06 23.02 4.07
# 29 62.0 49.54 4.21
# 30 108.83 44.78 3.15

# %%
# # 인라인 데이터 설정
# $Data << EOD
# 1 111.12 28.06 2.17
# 2 76.97 30.95 3.84
# 3 90.94 40.52 3.98
# 4 101.21 38.8 4.86
# 5 77.62 31.6 4.38
# 6 91.39 32.08 5.41
# 7 89.84 32.98 3.99
# 8 67.08 38.93 4.67
# 9 85.04 33.24 4.06
# 10 52.7 37.06 4.76
# 11 111.55 35.98 2.97
# 12 107.52 35.05 2.2
# 13 60.95 34.12 5.08
# 14 56.73 23.87 3.28
# 15 116.81 34.08 2.95
# 16 52.54 28.48 5.06
# 17 103.91 35.04 3.61
# 18 52.77 39.72 4.89
# 19 75.01 44.63 3.64
# 20 53.11 32.95 3.65
# 21 109.12 28.16 3.9
# 22 54.41 34.12 3.97
# 23 57.08 24.03 4.0
# 24 44.06 17.94 3.79
# 25 100.09 30.07 3.6
# 26 84.0 34.02 5.08
# 27 89.19 34.84 4.05
# 28 52.06 23.02 4.07
# 29 62.0 49.54 4.21
# 30 108.83 44.78 3.15
# EOD

# # 출력 설정
# #set terminal png size 200 500
# set terminal png font arial 10 size 330,210
# #set style point solid 0.5
# # 레이블 및 범위 설정
# #set xlabel "Test #"
# set ylabel "Latency(s)"
# set xrange [0:31]
# set yrange [0:130]
# set tics scale 1
# # 눈금 설정
# set xtics 5 
# set ytics 20
# set grid ytics
# # 범례 위치 설정
# #set key default
# #set key box
# #set key horiz
# set key right above width -4 font ", 8" spacing 1.2 at screen 0.97 , 1
# #set key inside left bottom spacing 1.2 font ", 8"



# # 플롯 데이터
# plot $Data using 1:2 with points pt 7 ps 0.5 lc rgb "blue" title "HPA Default", \
#      $Data using 1:3 with points pt 5 ps 0.5 lc rgb "orange" title "HPA Fast", \
#      $Data using 1:4 with points pt 9 ps 0.5 lc rgb "green" title "Proposed"

# # 대기 (터미널에서 실행 시 유용)
# # pause -1
# set output 'output.png'
# replot

# %%
# # 인라인 데이터 설정
# $Data << EOD
# 1 111.12 28.06 2.17
# 2 76.97 30.95 3.84
# 3 90.94 40.52 3.98
# 4 101.21 38.8 4.86
# 5 77.62 31.6 4.38
# 6 91.39 32.08 5.41
# 7 89.84 32.98 3.99
# 8 67.08 38.93 4.67
# 9 85.04 33.24 4.06
# 10 52.7 37.06 4.76
# 11 111.55 35.98 2.97
# 12 107.52 35.05 2.2
# 13 60.95 34.12 5.08
# 14 56.73 23.87 3.28
# 15 116.81 34.08 2.95
# 16 52.54 28.48 5.06
# 17 103.91 35.04 3.61
# 18 52.77 39.72 4.89
# 19 75.01 44.63 3.64
# 20 53.11 32.95 3.65
# 21 109.12 28.16 3.9
# 22 54.41 34.12 3.97
# 23 57.08 24.03 4.0
# 24 44.06 17.94 3.79
# 25 100.09 30.07 3.6
# 26 84.0 34.02 5.08
# 27 89.19 34.84 4.05
# 28 52.06 23.02 4.07
# 29 62.0 49.54 4.21
# 30 108.83 44.78 3.15
# EOD



# set terminal png font arial 10 size 330,200

# # 기본 설정
# set style data boxplot
# set style fill solid 1 border -1
# #set style boxplot outliers pointtype 7

# set multiplot
# #set style line 80 lt 0 lc rgb "#808080"
# set tics scale 1
# #set border 3 
# #set style line 81 lt 0 lc rgb "#808080" lw 0.5
# set grid ytics
# # 레이블 및 범위 설정
# #set xlabel " "
# set ylabel "Latency (s)"
# set ytics 20 
# set xtics ("HPA Default" 1, "HPA Fast" 2, "Proposed" 3) 
# set xrange [0.5:3.5]
# set yrange [0:130]
# set key right top spacing 1.5
# set origin 0.0,0.0
# set size 1.0,1.0
# # 박스 색상
# #set boxwidth 0.5 relative
# #set style fill solid 0.5
# #set palette defined (1 "blue", 2 "orange", 3 "green")

# #set arrow from graph 0,first 22 to graph 1,first 22 nohead lc rgb "#000000" front

# # 메인 박스 플롯
# #plot for [i=1:] $Data using (i):i:(i) with boxplot lc palette notitle
# #plot for [i=1:3] $Data using (i):i notitle  
# plot $Data using (1):2 with boxplot lc rgb "blue" notitle, \
#      $Data using (2):3 with boxplot lc rgb "orange" notitle, \
#      $Data using (3):4 with boxplot lc rgb "green" notitle 

# # 그래프 보조 인셋 (Proposed only)
# set size 0.38, 0.68
# set origin 0.595,0.2
# set xrange [3:4]
# set yrange [1.5:6.5]
# set ytics 2 
# unset grid
# unset ylabel 
# unset xtics
# set border -1
# #set ytics 1
# plot $Data using (3.5):4 with boxplot lc rgb "green" notitle
# # 표시
# # pause -1

# unset multiplot
# set output 'output.png'
# replot
