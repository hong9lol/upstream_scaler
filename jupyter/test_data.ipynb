# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import matplotlib as mat
from matplotlib import rc

# font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/Arial.ttf").get_name()
# font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/NANUMBARUNPENR.TTF").get_name()


def setPlotStyle():
    # plt.figure(dpi=300)
    # mat.rcParams["font.family"] = font_name
    mat.rcParams["font.size"] = 15
    mat.rcParams["legend.fontsize"] = 15
    mat.rcParams["lines.linewidth"] = 2
    mat.rcParams["lines.color"] = "r"
    mat.rcParams["axes.grid"] = 1
    mat.rcParams["axes.xmargin"] = 0.1
    mat.rcParams["axes.ymargin"] = 0.1
    mat.rcParams["mathtext.fontset"] = "dejavuserif"  # "cm", "stix", etc.
    mat.rcParams["figure.dpi"] = 500
    mat.rcParams["savefig.dpi"] = 500
# setPlotStyle()

# %%
data = [100, 100, 100, 100, 100, 100, 
        100,  120,  140,  160,  180,  200, 
        200,  240, 280,  320,  360,  400, 
        400,  460,  520,  580,  640,  700]
        # 700,  780,  860, 940,  1020, 1100,
        # 1100, 1200, 1300, 1400, 1500, 1600]
df = pd.DataFrame(data, columns=['Requests'])

import matplotlib.pyplot as plt
interval = 11
xlim = len(data) * 10
plt.figure(figsize=(10,5))
# for sd in social_deployment:
#     if sd == "nginx-thrift":
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd], 'ob--')
#     else:
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd])
#     plt.yticks(np.arange(0,2000,100))
#     plt.xticks(np.arange(0,xlim,60))

plt.plot(df.index * 10, df, 'og--')
# plt.yticks(np.arange(0,2000,100))
plt.xticks(np.arange(0,xlim,30))
plt.xlabel('Time(s)')
plt.ylabel('RPS')
# plt.title('(a) Linear Workload')
# plt.legend(df, fontsize=12, loc='best')
plt.grid()  # 그리드
# plt.ylim(0, 850)
plt.xlim(0, xlim)

plt.show()

# %%
data = [100, 100, 100, 100, 100, 100, 
        200, 200, 200, 200, 200, 200, 
        400, 400, 400, 400, 400, 400, 
        700, 700, 700, 700, 700, 700]
        # 700,  780,  860, 940,  1020, 1100,
        # 1100, 1200, 1300, 1400, 1500, 1600]
df = pd.DataFrame(data, columns=['Requests'])

import matplotlib.pyplot as plt
interval = 11
xlim = len(data) * 10
plt.figure(figsize=(10,5))
# for sd in social_deployment:
#     if sd == "nginx-thrift":
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd], 'ob--')
#     else:
#         plt.plot(df_npod.index * interval, df_usage[sd]*df_npod[sd])
#     plt.yticks(np.arange(0,2000,100))
#     plt.xticks(np.arange(0,xlim,60))

plt.plot(df.index * 10, df, 'or--')
# plt.yticks(np.arange(0,2000,100))
plt.xticks(np.arange(0,xlim,30))
plt.xlabel('Time(s)')
plt.ylabel('RPS')
# plt.title('(b) Spike Workload')
# plt.legend(df, fontsize=12, loc='best')
plt.grid()  # 그리드
# plt.ylim(0, 2000)
plt.xlim(0, xlim)

plt.show()

# %%
default = [
88235,
66745,
70897,
64289,
96552,
58424,
56130,
97160,
98638,
60528,
81690,
92585,
75844,
79211,
109135,
88164,
107846,
64536,
70425,
98965,
98671,
92869,
72561,
84496,
83781,
89673,
64718,
95189,
86092,
61902,
]

optimal = [
 30848,
 23486,
 23894,
 32114,
 27512,
 22114,
 30126,
 22642,
 30851,
 15547,
 20622,
 28901,
 31177,
 33183,
 25476,
 26430,
 44699,
 21013,
 38174,
 19571,
 23632,
 33624,
 26440,
 22695,
 30557,
 31042,
 27730,
 18655,
 17263,
 26830,
]

import matplotlib.pyplot as plt
import numpy as np
# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n, 1)

# setPlotStyle()

ylim = 120
default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
plt.figure(figsize=(5,4))
test_cnt = 30
x = list(range(1, test_cnt+1))
plt.xlabel('Test #')
plt.ylabel('Scaling Latency(s)')
# plt.title('Scaling Latency of ')

plt.yticks(np.arange(0,ylim,20))

plt.ylim(0, ylim)
plt.xlim(0, test_cnt+1)

# fig, ax = plt.subplots()    
color = 'tab:blue'
plt.scatter(x, default, c=color, s=30, label="Default",
            alpha=1, edgecolors='none')

color = 'tab:orange'
plt.scatter(x, optimal, c=color, s=30, label="Optimal",
            alpha=1, edgecolors='none', marker='s')


# handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
# plt.legend(handles, labels, 
plt.legend(loc="upper right", title="Mode",fontsize=8, title_fontsize=10)
# plt.grid(False)
plt.grid(axis='y')
# plt.scatter(x, default, c="tab:blue", alpha=0.95, edgecolors='none')
# plt.scatter(x, optimal)
plt.show()

# %%
default = [
88235,
66745,
70897,
64289,
96552,
58424,
56130,
97160,
98638,
60528,
81690,
92585,
75844,
79211,
109135,
88164,
107846,
64536,
70425,
98965,
98671,
92869,
72561,
84496,
83781,
89673,
64718,
95189,
86092,
61902,
]

optimal = [
 30848,
 23486,
 23894,
 32114,
 27512,
 22114,
 30126,
 22642,
 30851,
 15547,
 20622,
 28901,
 31177,
 33183,
 25476,
 26430,
 44699,
 21013,
 38174,
 19571,
 23632,
 33624,
 26440,
 22695,
 30557,
 31042,
 27730,
 18655,
 17263,
 26830,
]
upstream = [
 4058,
 4154,
 3061,
 4742,
 3412,
 4010,
 4781,
 3367,
 3858,
 4827,
 4172,
 3484,
 4872,
 3334,
 3831,
 3956,
 4640,
 4777,
 3892,
 5131,
 3861,
 3364,
 4730,
 4241,
 3656,
 4646,
 4480,
 4220,
 4493,
 4346,
]

import matplotlib.pyplot as plt
import numpy as np
# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n, 1)

# setPlotStyle()

ylim = 120
default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
upstream = list(map(get_seconds, upstream))
plt.figure(figsize=(5,4))
test_cnt = 30
x = list(range(1, test_cnt+1))
plt.xlabel('Test #')
plt.ylabel('Scaling Latency(s)')
# plt.title('Scaling Latency of ')

plt.yticks(np.arange(0,ylim,20))

plt.ylim(0, ylim)
plt.xlim(0, test_cnt+1)

# fig, ax = plt.subplots()    
color = 'tab:blue'
plt.scatter(x, default, c=color, s=30, label="Default",
            alpha=1, edgecolors='none')

color = 'tab:orange'
plt.scatter(x, optimal, c=color, s=30, label="Optimal",
            alpha=1, edgecolors='none', marker='s')

color = 'tab:green'
plt.scatter(x, upstream, c=color, s=30, label="UHPA",
            alpha=1, edgecolors='none', marker='D')


# handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
# plt.legend(handles, labels, 
plt.legend(loc="upper right", title="Mode",fontsize=8, title_fontsize=10)
# plt.grid(False)
plt.grid(axis='y')
# plt.scatter(x, default, c="tab:blue", alpha=0.95, edgecolors='none')
# plt.scatter(x, optimal)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

default = [
88235,
66745,
70897,
64289,
96552,
58424,
56130,
97160,
98638,
60528,
81690,
92585,
75844,
79211,
109135,
88164,
107846,
64536,
70425,
98965,
98671,
92869,
72561,
84496,
83781,
89673,
64718,
95189,
86092,
61902,
]

optimal = [
 30848,
 23486,
 23894,
 32114,
 27512,
 22114,
 30126,
 22642,
 30851,
 15547,
 20622,
 28901,
 31177,
 33183,
 25476,
 26430,
 44699,
 21013,
 38174,
 19571,
 23632,
 33624,
 26440,
 22695,
 30557,
 31042,
 27730,
 18655,
 17263,
 26830,
]
upstream = [
 4058,
 4154,
 3061,
 4742,
 3412,
 4010,
 4781,
 3367,
 3858,
 4827,
 4172,
 3484,
 4872,
 3334,
 3831,
 3956,
 4640,
 4777,
 3892,
 5131,
 3861,
 3364,
 4730,
 4241,
 3656,
 4646,
 4480,
 4220,
 4493,
 4346,
]

# Random test data
# np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=5) for std in range(1, 3)]
# labels = ['Default', 'x2', 'x3']
print(all_data)

# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n)

default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
upstream = list(map(get_seconds, upstream))



all_data = []
all_data.append(default)
all_data.append(optimal)
print(all_data)

labels = ['Default', 'Optimal']
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3.5, 6))

# rectangular box plot
bplot1 = ax.boxplot(all_data,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels,
                        #  showmeans=True, 
                        #  meanline=True
                         )  # will be used to label x-ticks
# ax.set_title('Rectangular box plot')

# # notch shape box plot
# bplot2 = axes[1].boxplot(all_data,
#                          notch=True,  # notch shape
#                          vert=True,  # vertical box alignment
#                          patch_artist=True,  # fill with color
#                          labels=labels)  # will be used to label x-ticks
# axes[1].set_title('Notched box plot')

# fill with colors
# colors = ['pink', 'lightblue', 'lightgreen']
colors = ['tab:blue', 'tab:orange']
for patch, color in zip(bplot1['boxes'], colors):
    patch.set_facecolor(color)

for i, _ in enumerate(labels):
    mean_line = bplot1['medians'][i]  # 평균값 요소에 접근
    mean_line.set_color('black')  # 평균값 선 색상 변경
    mean_line.set_linewidth(1.5)  # 평균값 선 굵기 변경

# adding horizontal grid lines
# for ax in axes:
ax.yaxis.grid(True)
ax.set_xlabel(' ')
# ax.set_ylabel('Scaling Latency(s)')

ylim = 120
plt.yticks(np.arange(0,ylim,20))
plt.ylim(0, ylim)
plt.show()
# Out:
# [array([-0.67329276, -0.34446759,  0.99379889,  0.5083144 , -0.68274512]), array([-3.57269837,  0.50276628,  1.3475584 , -3.42795748,  1.36663795])]
# [[88, 67, 71, 64, 97, 58, 56, 97, 99, 61, 82, 93, 76, 79, 109, 88, 108, 65, 70, 99, 99, 93, 73, 84, 84, 90, 65, 95, 86, 62], [31, 23, 24, 32, 28, 22, 30, 23, 31, 16, 21, 29, 31, 33, 25, 26, 45, 21, 38, 20, 24, 34, 26, 23, 31, 31, 28, 19, 17, 27]]

# %%
import matplotlib.pyplot as plt
import numpy as np

default = [
88235,
66745,
70897,
64289,
96552,
58424,
56130,
97160,
98638,
60528,
81690,
92585,
75844,
79211,
109135,
88164,
107846,
64536,
70425,
98965,
98671,
92869,
72561,
84496,
83781,
89673,
64718,
95189,
86092,
61902,
]

optimal = [
 30848,
 23486,
 23894,
 32114,
 27512,
 22114,
 30126,
 22642,
 30851,
 15547,
 20622,
 28901,
 31177,
 33183,
 25476,
 26430,
 44699,
 21013,
 38174,
 19571,
 23632,
 33624,
 26440,
 22695,
 30557,
 31042,
 27730,
 18655,
 17263,
 26830,
]
upstream = [
 4058,
 4154,
 3061,
 4742,
 3412,
 4010,
 4781,
 3367,
 3858,
 4827,
 4172,
 3484,
 4872,
 3334,
 3831,
 3956,
 4640,
 4777,
 3892,
 5131,
 3861,
 3364,
 4730,
 4241,
 3656,
 4646,
 4480,
 4220,
 4493,
 4346,
]

# Random test data
# np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=5) for std in range(1, 3)]
# labels = ['Default', 'x2', 'x3']
print(all_data)

# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n, 1)

default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
upstream = list(map(get_seconds, upstream))


all_data = []
all_data.append(default)
all_data.append(optimal)
all_data.append(upstream)


labels = ['Default', 'Optimal', 'UHPA']
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3.5, 6))


# rectangular box plot
bplot1 = ax.boxplot(all_data,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels,
                        #  showmeans=True, 
                        #  meanline=True
                         )  # will be used to label x-ticks
# ax.set_title('Rectangular box plot')

# # notch shape box plot
# bplot2 = axes[1].boxplot(all_data,
#                          notch=True,  # notch shape
#                          vert=True,  # vertical box alignment
#                          patch_artist=True,  # fill with color
#                          labels=labels)  # will be used to label x-ticks
# axes[1].set_title('Notched box plot')

# fill with colors
# colors = ['pink', 'lightblue', 'lightgreen']
colors = ['tab:blue', 'tab:orange']
for patch, color in zip(bplot1['boxes'], colors):
    patch.set_facecolor(color)

for i, _ in enumerate(labels):
    mean_line = bplot1['medians'][i]  # 평균값 요소에 접근
    mean_line.set_color('red')  # 평균값 선 색상 변경
    mean_line.set_linewidth(1.5)  # 평균값 선 굵기 변경

# adding horizontal grid lines
# for ax in axes:

ax.yaxis.grid(True)
ax.set_xlabel(' ')
# ax.set_ylabel('Scaling Latency(s)')

ylim = 120
plt.yticks(np.arange(0,ylim,20))
plt.ylim(0, ylim)
plt.show()
# Out:
# [array([-0.52626089, -0.3490126 ,  1.52099903,  0.30811896, -1.37704862]), array([ 1.43337351, -3.16191161,  0.25958971,  0.32984792, -1.31679674])]

# %%
# !pip install mne
# Out:
# Requirement already satisfied: mne in /home/leejaehong/anaconda3/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.21.2 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (1.24.3)
# Requirement already satisfied: scipy>=1.7.1 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (1.11.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (3.7.2)
# Requirement already satisfied: tqdm in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (4.65.0)
# Requirement already satisfied: pooch>=1.5 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (1.8.1)
# Requirement already satisfied: decorator in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (5.1.1)
# Requirement already satisfied: packaging in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (23.1)
# Requirement already satisfied: jinja2 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from mne) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from pooch>=1.5->mne) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from jinja2->mne) (2.1.1)
# Requirement already satisfied: six>=1.5 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/leejaehong/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.7.22)

# %%
import matplotlib.pyplot as plt
import numpy as np

default = [
88235,
66745,
70897,
64289,
96552,
58424,
56130,
97160,
98638,
60528,
81690,
92585,
75844,
79211,
109135,
88164,
107846,
64536,
70425,
98965,
98671,
92869,
72561,
84496,
83781,
89673,
64718,
95189,
86092,
61902,
]

optimal = [
 30848,
 23486,
 23894,
 32114,
 27512,
 22114,
 30126,
 22642,
 30851,
 15547,
 20622,
 28901,
 31177,
 33183,
 25476,
 26430,
 44699,
 21013,
 38174,
 19571,
 23632,
 33624,
 26440,
 22695,
 30557,
 31042,
 27730,
 18655,
 17263,
 26830,
]
upstream = [
 4058,
 4154,
 3061,
 4742,
 3412,
 4010,
 4781,
 3367,
 3858,
 4827,
 4172,
 3484,
 4872,
 3334,
 3831,
 3956,
 4640,
 4777,
 3892,
 5131,
 3861,
 3364,
 4730,
 4241,
 3656,
 4646,
 4480,
 4220,
 4493,
 4346,
]

# Random test data
# np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=5) for std in range(1, 3)]
# labels = ['Default', 'x2', 'x3']
print(all_data)

# map 함수 이용
def get_seconds(n):
    n *= 0.001
    return round(n, 1)

default = list(map(get_seconds, default))
optimal = list(map(get_seconds, optimal))
upstream = list(map(get_seconds, upstream))


all_data = []
all_data.append(default)
all_data.append(optimal)
all_data.append(upstream)


labels = ['Default', 'Optimal', 'UHPA']
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3.5, 6))


# rectangular box plot
bplot1 = ax.boxplot(all_data,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels,
                        #  showmeans=True, 
                        #  meanline=True
                         )  # will be used to label x-ticks
# ax.set_title('Rectangular box plot')

# # notch shape box plot
# bplot2 = axes[1].boxplot(all_data,
#                          notch=True,  # notch shape
#                          vert=True,  # vertical box alignment
#                          patch_artist=True,  # fill with color
#                          labels=labels)  # will be used to label x-ticks
# axes[1].set_title('Notched box plot')

# fill with colors
# colors = ['pink', 'lightblue', 'lightgreen']
colors = ['tab:blue', 'tab:orange']
for patch, color in zip(bplot1['boxes'], colors):
    patch.set_facecolor(color)

for i, _ in enumerate(labels):
    mean_line = bplot1['medians'][i]  # 평균값 요소에 접근
    mean_line.set_color('red')  # 평균값 선 색상 변경
    mean_line.set_linewidth(1.5)  # 평균값 선 굵기 변경

# adding horizontal grid lines
# for ax in axes:

ax.yaxis.grid(True)
ax.set_xlabel(' ')
# ax.set_ylabel('Scaling Latency(s)')


# rectangular box plot
# bplot1 = ax.boxplot(all_data,
#                          vert=True,  # vertical box alignment
#                          patch_artist=True,  # fill with color
#                          labels=labels
#                          )  # will be used to label x-ticks
# ax.set_title('Rectangular box plot')

# # notch shape box plot
# bplot2 = axes[1].boxplot(all_data,
#                          notch=True,  # notch shape
#                          vert=True,  # vertical box alignment
#                          patch_artist=True,  # fill with color
#                          labels=labels)  # will be used to label x-ticks
# axes[1].set_title('Notched box plot')

# fill with colors
# # colors = ['pink', 'lightblue', 'lightgreen']
# colors = ['tab:blue', 'tab:orange', 'tab:green']
# for patch, color in zip(bplot1['boxes'], colors):
#     patch.set_facecolor(color)

# adding horizontal grid lines
# for ax in axes:

ax.yaxis.grid(True)
ax.set_xlabel(' ')
# ax.set_ylabel('Scaling Latency(s)')

# ax.imshow(data, extent=(0, 100, 0, 100), origin='lower')
# print(data[10:11, 10:11])

axins = ax.inset_axes([0.5, 0.5, 0.45, 0.45],xlim=(2.8, 3.2), ylim=(2,6))

bplot2 = axins.boxplot(upstream,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                        labels=[""],
                         positions=[3]
                         )  

mean_line = bplot2['medians'][0]  # 평균값 요소에 접근
mean_line.set_color('red')  # 평균값 선 색상 변경
mean_line.set_linewidth(1.5)  # 평균값 선 굵기 변경
# colors = ['tab:blue', 'tab:orange', 'tab:green']
# for patch, color in zip(bplot1['boxes'], colors):
#     patch.set_facecolor(color)
# imshow((1), extent=(2.8, 3.2, 2, 7), origin='lower')

# axins.set_xticklabels('UHPA')
# axins.set_yticklabels('')

colors = ['tab:green']
for patch, color in zip(bplot2['boxes'], colors):
    patch.set_facecolor(color)

for axis in ['top', 'bottom', 'left', 'right']:
    axins.spines[axis].set_linewidth(1.5)
    

# axins.set_xlim(2.8, 3.2)
axins.set_ylim(2, 6)
axins.set_yticks(np.arange(2, 7,1))
indicator = ax.indicate_inset_zoom(axins)

ylim = 120
plt.yticks(np.arange(0,ylim,20))
plt.ylim(0, ylim)
plt.show()
# Out:
# [array([ 0.40321019, -0.88501542,  0.13614196, -1.66894045,  0.8928416 ]), array([-0.38967878, -0.19370353, -0.47315565, -1.62895197,  1.77417895])]

# %%
import matplotlib.pyplot as plt

# CPU limit values as x-axis
cpu_limits = [1.0, 1.5, 2.0, 2.5]

# Performance values for each configuration as y-axis for dataset 1
default_performance_1 = [1.08, 2.00, 2.00, 2.83]
optimal_performance_1 = [2.00, 2.67, 4.42, 6.08]
uhpa_performance_1 = [2.58, 5.50, 6.75, 6.75]

# Performance values for each configuration as y-axis for dataset 2 (Same data used for illustration)
default_performance_2 = [1.08, 2.00, 2.00, 2.83]
optimal_performance_2 = [2.00, 2.67, 4.42, 6.08]
uhpa_performance_2 = [2.58, 5.50, 6.75, 6.75]


# Performance values for each configuration as y-axis for dataset 2 (Same data used for illustration)
default_performance_3 = [1.08, 2.00, 2.00, 2.83]
optimal_performance_3 = [2.00, 2.67, 4.42, 6.08]
uhpa_performance_3 = [2.58, 5.50, 6.75, 6.75]

# Creating two subplots
fig, axs = plt.subplots(1, 3, figsize=(12, 5))
plt.subplots_adjust(left=None, bottom=None, right=1, top=0.5, wspace=None, hspace=None)

# Plotting for dataset 1
axs[0].plot(cpu_limits, default_performance_1, marker='o', color='blue', linestyle='-', label='Default')
axs[0].plot(cpu_limits, optimal_performance_1, marker='s', color='green', linestyle='--', label='Optimal')
axs[0].plot(cpu_limits, uhpa_performance_1, marker='D', color='red', linestyle='-.', label='UHPA')
# axs[0].set_title('Dataset 1 Performance')
axs[0].set_xlabel('CPU Limit')
axs[0].set_ylabel('Performance')


# Plotting for dataset 2
axs[1].plot(cpu_limits, default_performance_2, marker='o', color='blue', linestyle='-', label='Default')
axs[1].plot(cpu_limits, optimal_performance_2, marker='s', color='green', linestyle='--', label='Optimal')
axs[1].plot(cpu_limits, uhpa_performance_2, marker='D', color='red', linestyle='-.', label='UHPA')
# axs[1].set_title('Dataset 2 Performance')
axs[1].set_xlabel('CPU Limit')
axs[1].set_ylabel('Performance')


# Plotting for dataset 2
axs[2].plot(cpu_limits, default_performance_3, marker='o', color='blue', linestyle='-', label='Default')
axs[2].plot(cpu_limits, optimal_performance_3, marker='s', color='orange', linestyle='--', label='Optimal')
axs[2].plot(cpu_limits, uhpa_performance_3, marker='D', color='green', linestyle='-.', label='UHPA')
# axs[1].set_title('Dataset 2 Performance')
axs[2].set_xlabel('CPU Limit')
axs[2].set_ylabel('Replicas')

# Adjusting the legend to be on top of the first subplot, horizontally aligned
axs[1].legend(loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=3)

xlim = len(data) * 10
plt.xticks(np.arange(1,3,0.5))
# plt.tight_layout()
plt.show()


# Adding legend

# %% [markdown]
# ****
